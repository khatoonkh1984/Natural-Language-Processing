# %% [markdown]
# ## Sentiment Analysis: Determining the polarity of a text (positive or negative).

# %% [markdown]
# ## Data

# %% [markdown]
# [IMDB](http://ai.stanford.edu/~amaas/data/sentiment/) Dataset
# - A dataset for binary sentiment classification.
# - It provides a set of 25,000 highly polar movie reviews for training, and 25,000 for testing.
#
#
# **Note**: to run the following codes, you need to dowloand the dataset from the provided link and change the `data_dir` in the following cell accordingly.

# %% [markdown]
# ## Libraries

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

import os
import re
import sys
import spacy  # just for NLP
import pickle
import numpy as np

from glob import glob
import tqdm

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import DataLoader, Dataset

from utils import *
from data_utils import Vocabulary, tokenizer
from train_utils import train


# setup
NLP = spacy.load('en_core_web_sm')  # NLP toolkit

# %% [markdown]
# ## Tokenizing

# %%
text = """
Bromwell High is a cartoon comedy. 
It ran at the same time as some other programs about school life, such as 'Teachers'. 
My 35 years in the teaching profession lead me to believe that Bromwell High's 
satire is much closer to reality than is 'Teachers'. 
The scramble to survive financially, the insightful students who can see 
right through their pathetic teachers' pomp, the pettiness of the whole situation, 
all remind me of the schools I knew and their students. 
When I saw the episode in which a student repeatedly tried to burn down the school, 
I immediately recalled ......... at .......... High. 
A classic line: INSPECTOR: I'm here to sack one of your teachers. 
STUDENT: Welcome to Bromwell High. 
I expect that many adults of my age think that Bromwell High is far fetched. 
What a pity that it isn't!!!
"""

# %%
''' Remove the followimg characters and replace with space  '''
text = re.sub(r"[\*\"“”\n\\…\+\-\/\=\(\)‘•:\[\]\|’;]", " ", str(text)) 
print(text)
# Out:
#  Bromwell High is a cartoon comedy.  It ran at the same time as some other programs about school life, such as 'Teachers'.  My 35 years in the teaching profession lead me to believe that Bromwell High's  satire is much closer to reality than is 'Teachers'.  The scramble to survive financially, the insightful students who can see  right through their pathetic teachers' pomp, the pettiness of the whole situation,  all remind me of the schools I knew and their students.  When I saw the episode in which a student repeatedly tried to burn down the school,  I immediately recalled ......... at .......... High.  A classic line  INSPECTOR  I'm here to sack one of your teachers.  STUDENT  Welcome to Bromwell High.  I expect that many adults of my age think that Bromwell High is far fetched.  What a pity that it isn't!!!

# %%
'''Replace some spaces with one space'''
text = re.sub(r"[ ]+", " ", text)
print(text)
# Out:
#  Bromwell High is a cartoon comedy. It ran at the same time as some other programs about school life, such as 'Teachers'. My 35 years in the teaching profession lead me to believe that Bromwell High's satire is much closer to reality than is 'Teachers'. The scramble to survive financially, the insightful students who can see right through their pathetic teachers' pomp, the pettiness of the whole situation, all remind me of the schools I knew and their students. When I saw the episode in which a student repeatedly tried to burn down the school, I immediately recalled ......... at .......... High. A classic line INSPECTOR I'm here to sack one of your teachers. STUDENT Welcome to Bromwell High. I expect that many adults of my age think that Bromwell High is far fetched. What a pity that it isn't!!!

# %%
'''Replace some signs ! with one !'''

text = re.sub(r"\!+", "!", text)
print(text)
# Out:
#  Bromwell High is a cartoon comedy. It ran at the same time as some other programs about school life, such as 'Teachers'. My 35 years in the teaching profession lead me to believe that Bromwell High's satire is much closer to reality than is 'Teachers'. The scramble to survive financially, the insightful students who can see right through their pathetic teachers' pomp, the pettiness of the whole situation, all remind me of the schools I knew and their students. When I saw the episode in which a student repeatedly tried to burn down the school, I immediately recalled ......... at .......... High. A classic line INSPECTOR I'm here to sack one of your teachers. STUDENT Welcome to Bromwell High. I expect that many adults of my age think that Bromwell High is far fetched. What a pity that it isn't!

# %%
'''tonenize'''

tokens = [w.text for w in NLP.tokenizer(text)]
print(tokens)
# Out:
# [' ', 'Bromwell', 'High', 'is', 'a', 'cartoon', 'comedy', '.', 'It', 'ran', 'at', 'the', 'same', 'time', 'as', 'some', 'other', 'programs', 'about', 'school', 'life', ',', 'such', 'as', "'", 'Teachers', "'", '.', 'My', '35', 'years', 'in', 'the', 'teaching', 'profession', 'lead', 'me', 'to', 'believe', 'that', 'Bromwell', 'High', "'s", 'satire', 'is', 'much', 'closer', 'to', 'reality', 'than', 'is', "'", 'Teachers', "'", '.', 'The', 'scramble', 'to', 'survive', 'financially', ',', 'the', 'insightful', 'students', 'who', 'can', 'see', 'right', 'through', 'their', 'pathetic', 'teachers', "'", 'pomp', ',', 'the', 'pettiness', 'of', 'the', 'whole', 'situation', ',', 'all', 'remind', 'me', 'of', 'the', 'schools', 'I', 'knew', 'and', 'their', 'students', '.', 'When', 'I', 'saw', 'the', 'episode', 'in', 'which', 'a', 'student', 'repeatedly', 'tried', 'to', 'burn', 'down', 'the', 'school', ',', 'I', 'immediately', 'recalled', '.........', 'at', '..........', 'High', '.', 'A', 'classic', 'line', 'INSPECTOR', 'I', "'m", 'here', 'to', 'sack', 'one', 'of', 'your', 'teachers', '.', 'STUDENT', 'Welcome', 'to', 'Bromwell', 'High', '.', 'I', 'expect', 'that', 'many', 'adults', 'of', 'my', 'age', 'think', 'that', 'Bromwell', 'High', 'is', 'far', 'fetched', '.', 'What', 'a', 'pity', 'that', 'it', 'is', "n't", '!']

# %% [markdown]
# ### Tokenizer and Vocabulary

# %% [markdown]
# We have defined a function in `utils.py`, which gets the inputs text and splits it to a sequence of tokens. We have used **SpaCy** toolkit for tokeniztion and you need to install it to run the codes.

# %% [markdown]
# ```python
# def tokenizer(text):
#     text = re.sub(r"[\*\"“”\n\\…\+\-\/\=\(\)‘•:\[\]\|’;]", " ", str(text))
#     text = re.sub(r"[ ]+", " ", text)
#     text = re.sub(r"\!+", "!", text)
#     text = re.sub(r"\,+", ",", text)
#     text = re.sub(r"\?+", "?", text)
#     return [x.text for x in NLP.tokenizer(text) if x.text != " "]
# ```

# %%
data_dir = 'dataset/aclImdb/'

vocab_path = 'vocab.pkl'

# parameters
max_len = 200  # By this initilazatio we consider just 200 character of each text. we determine based on mean + 2 * sigma
min_count = 10     #we replace every token which repeat less than 10 times with the spetial token. This is UNK = '<unk>'. 
batch_size = 50

# %%
import splitfolders
input_folder='dataset/aclImdb/test/'
splitfolders.ratio(input_folder, output="dataset/aclImdb/valid", seed=1337, ratio=(0.88, 0.1, 0.02))
# Out:
# Copying files: 0 files [00:00, ? files/s]
# Copying files: 1 files [00:02,  2.39s/ files]
# Copying files: 9 files [00:02,  4.90 files/s]
# Copying files: 18 files [00:02, 11.22 files/s]
# Copying files: 28 files [00:02, 19.67 files/s]
# Copying files: 38 files [00:02, 29.22 files/s]
# Copying files: 48 files [00:02, 39.22 files/s]
# Copying files: 57 files [00:03, 47.53 files/s]
# Copying files: 68 files [00:03, 58.82 files/s]
# Copying files: 78 files [00:03, 66.00 files/s]
# Copying files: 88 files [00:03, 72.69 files/s]
# Copying files: 98 files [00:03, 74.99 files/s]
# Copying files: 107 files [00:03, 78.15 files/s]
# Copying files: 117 files [00:03, 82.57 files/s]
# Copying files: 127 files [00:03, 86.33 files/s]
# Copying files: 137 files [00:03, 88.64 files/s]
# Copying files: 147 files [00:04, 84.52 files/s]
# Copying files: 156 files [00:04, 79.60 files/s]
# Copying files: 166 files [00:04, 83.43 files/s]
# Copying files: 176 files [00:04, 87.43 files/s]
# Copying files: 186 files [00:04, 90.42 files/s]
# Copying files: 196 files [00:04, 90.83 files/s]
# Copying files: 206 files [00:04, 91.37 files/s]
# Copying files: 217 files [00:04, 94.26 files/s]
# Copying files: 227 files [00:04, 93.01 files/s]
# Copying files: 237 files [00:04, 93.67 files/s]
# Copying files: 247 files [00:05, 94.42 files/s]
# Copying files: 257 files [00:05, 94.15 files/s]
# Copying files: 267 files [00:05, 94.49 files/s]
# Copying files: 277 files [00:05, 95.00 files/s]
# Copying files: 287 files [00:05, 89.49 files/s]
# Copying files: 297 files [00:05, 87.34 files/s]
# Copying files: 307 files [00:05, 89.82 files/s]
# Copying files: 317 files [00:05, 91.65 files/s]
# Copying files: 327 files [00:05, 90.70 files/s]
# Copying files: 337 files [00:06, 92.03 files/s]
# Copying files: 347 files [00:06, 91.96 files/s]
# Copying files: 357 files [00:06, 93.46 files/s]
# Copying files: 367 files [00:06, 89.46 files/s]
# Copying files: 376 files [00:06, 85.37 files/s]
# Copying files: 386 files [00:06, 88.18 files/s]
# Copying files: 395 files [00:06, 85.38 files/s]
# Copying files: 404 files [00:06, 85.03 files/s]
# Copying files: 413 files [00:06, 85.95 files/s]
# Copying files: 423 files [00:07, 89.71 files/s]
# Copying files: 433 files [00:07, 91.37 files/s]
# Copying files: 443 files [00:07, 91.25 files/s]
# Copying files: 453 files [00:07, 92.71 files/s]
# Copying files: 463 files [00:07, 92.69 files/s]
# Copying files: 473 files [00:07, 92.16 files/s]
# Copying files: 483 files [00:07, 93.61 files/s]
# Copying files: 493 files [00:07, 84.75 files/s]
# Copying files: 503 files [00:07, 86.98 files/s]
# Copying files: 513 files [00:08, 89.80 files/s]
# Copying files: 523 files [00:08, 90.64 files/s]
# Copying files: 533 files [00:08, 91.99 files/s]
# Copying files: 543 files [00:08, 93.48 files/s]
# Copying files: 553 files [00:08, 95.09 files/s]
# Copying files: 563 files [00:08, 94.88 files/s]
# Copying files: 573 files [00:08, 92.63 files/s]
# Copying files: 583 files [00:08, 92.38 files/s]
# Copying files: 593 files [00:08, 94.02 files/s]
# Copying files: 603 files [00:09, 92.83 files/s]
# Copying files: 613 files [00:09, 93.03 files/s]
# Copying files: 623 files [00:09, 93.17 files/s]
# Copying files: 633 files [00:09, 91.99 files/s]
# Copying files: 643 files [00:09, 93.48 files/s]
# Copying files: 653 files [00:09, 92.71 files/s]
# Copying files: 663 files [00:09, 91.67 files/s]
# Copying files: 673 files [00:09, 92.47 files/s]
# Copying files: 683 files [00:09, 93.04 files/s]
# Copying files: 694 files [00:09, 95.98 files/s]
# Copying files: 704 files [00:10, 92.90 files/s]
# Copying files: 714 files [00:10, 92.32 files/s]
# Copying files: 724 files [00:10, 91.66 files/s]
# Copying files: 734 files [00:10, 91.70 files/s]
# Copying files: 744 files [00:10, 91.73 files/s]
# Copying files: 754 files [00:10, 92.26 files/s]
# Copying files: 764 files [00:10, 92.38 files/s]
# Copying files: 774 files [00:10, 92.20 files/s]
# Copying files: 784 files [00:10, 92.59 files/s]
# Copying files: 794 files [00:11, 93.91 files/s]
# Copying files: 804 files [00:11, 93.01 files/s]
# Copying files: 814 files [00:11, 92.64 files/s]
# Copying files: 824 files [00:11, 91.63 files/s]
# Copying files: 834 files [00:11, 92.96 files/s]
# Copying files: 844 files [00:11, 90.35 files/s]
# Copying files: 854 files [00:11, 86.32 files/s]
# Copying files: 863 files [00:11, 86.86 files/s]
# Copying files: 873 files [00:11, 89.28 files/s]
# Copying files: 882 files [00:12, 89.00 files/s]
# Copying files: 891 files [00:12, 87.80 files/s]
# Copying files: 900 files [00:12, 84.80 files/s]
# Copying files: 909 files [00:12, 85.32 files/s]
# Copying files: 919 files [00:12, 87.52 files/s]
# Copying files: 929 files [00:12, 89.81 files/s]
# Copying files: 938 files [00:12, 88.61 files/s]
# Copying files: 947 files [00:12, 88.77 files/s]
# Copying files: 957 files [00:12, 90.73 files/s]
# Copying files: 967 files [00:13, 92.10 files/s]
# Copying files: 977 files [00:13, 88.03 files/s]
# Copying files: 986 files [00:13, 79.11 files/s]
# Copying files: 995 files [00:13, 78.88 files/s]
# Copying files: 1004 files [00:13, 78.71 files/s]
# Copying files: 1013 files [00:13, 80.24 files/s]
# Copying files: 1022 files [00:13, 80.29 files/s]
# Copying files: 1031 files [00:13, 79.48 files/s]
# Copying files: 1041 files [00:13, 83.72 files/s]
# Copying files: 1050 files [00:14, 79.94 files/s]
# Copying files: 1059 files [00:14, 80.08 files/s]
# Copying files: 1068 files [00:14, 81.46 files/s]
# Copying files: 1078 files [00:14, 84.50 files/s]
# Copying files: 1088 files [00:14, 88.10 files/s]
# Copying files: 1098 files [00:14, 89.21 files/s]
# Copying files: 1107 files [00:14, 88.95 files/s]
# Copying files: 1116 files [00:14, 88.25 files/s]
# Copying files: 1125 files [00:14, 83.48 files/s]
# Copying files: 1134 files [00:15, 82.77 files/s]
# Copying files: 1143 files [00:15, 81.62 files/s]
# Copying files: 1152 files [00:15, 80.18 files/s]
# Copying files: 1162 files [00:15, 84.70 files/s]
# Copying files: 1172 files [00:15, 87.53 files/s]
# Copying files: 1183 files [00:15, 91.81 files/s]
# Copying files: 1194 files [00:15, 95.09 files/s]
# Copying files: 1205 files [00:15, 96.60 files/s]
# Copying files: 1215 files [00:15, 93.86 files/s]
# Copying files: 1225 files [00:16, 91.26 files/s]
# Copying files: 1235 files [00:16, 92.16 files/s]
# Copying files: 1245 files [00:16, 93.33 files/s]
# Copying files: 1255 files [00:16, 93.90 files/s]
# Copying files: 1265 files [00:16, 95.39 files/s]
# Copying files: 1275 files [00:16, 95.36 files/s]
# Copying files: 1285 files [00:16, 95.61 files/s]
# Copying files: 1295 files [00:16, 95.79 files/s]
# Copying files: 1305 files [00:16, 95.10 files/s]
# Copying files: 1315 files [00:17, 94.62 files/s]
# Copying files: 1325 files [00:17, 95.09 files/s]
# Copying files: 1335 files [00:17, 95.15 files/s]
# Copying files: 1345 files [00:17, 96.29 files/s]
# Copying files: 1355 files [00:17, 96.83 files/s]
# Copying files: 1365 files [00:17, 95.81 files/s]
# Copying files: 1375 files [00:17, 94.84 files/s]
# Copying files: 1386 files [00:17, 97.27 files/s]
# Copying files: 1396 files [00:17, 97.24 files/s]
# Copying files: 1406 files [00:17, 97.21 files/s]
# Copying files: 1416 files [00:18, 97.75 files/s]
# Copying files: 1426 files [00:18, 97.57 files/s]
# Copying files: 1436 files [00:18, 94.69 files/s]
# Copying files: 1446 files [00:18, 84.78 files/s]
# Copying files: 1457 files [00:18, 89.83 files/s]
# Copying files: 1467 files [00:18, 91.86 files/s]
# Copying files: 1477 files [00:18, 92.34 files/s]
# Copying files: 1487 files [00:18, 93.72 files/s]
# Copying files: 1497 files [00:18, 92.62 files/s]
# Copying files: 1507 files [00:19, 92.89 files/s]
# Copying files: 1517 files [00:19, 93.59 files/s]
# Copying files: 1527 files [00:19, 93.83 files/s]
# Copying files: 1537 files [00:19, 94.80 files/s]
# Copying files: 1547 files [00:19, 95.77 files/s]
# Copying files: 1557 files [00:19, 91.93 files/s]
# Copying files: 1567 files [00:19, 93.96 files/s]
# Copying files: 1578 files [00:19, 96.37 files/s]
# Copying files: 1588 files [00:19, 96.87 files/s]
# Copying files: 1599 files [00:19, 98.13 files/s]
# Copying files: 1609 files [00:20, 98.40 files/s]
# Copying files: 1619 files [00:20, 98.60 files/s]
# Copying files: 1630 files [00:20, 99.62 files/s]
# Copying files: 1640 files [00:20, 99.46 files/s]
# Copying files: 1650 files [00:20, 99.35 files/s]
# Copying files: 1661 files [00:20, 99.57 files/s]
# Copying files: 1672 files [00:20, 98.89 files/s]
# Copying files: 1683 files [00:20, 99.52 files/s]
# Copying files: 1693 files [00:20, 99.39 files/s]
# Copying files: 1703 files [00:21, 96.80 files/s]
# Copying files: 1713 files [00:21, 97.45 files/s]
# Copying files: 1724 files [00:21, 98.81 files/s]
# Copying files: 1735 files [00:21, 99.48 files/s]
# Copying files: 1745 files [00:21, 99.36 files/s]
# Copying files: 1755 files [00:21, 98.71 files/s]
# Copying files: 1765 files [00:21, 98.81 files/s]
# Copying files: 1775 files [00:21, 98.87 files/s]
# Copying files: 1785 files [00:21, 98.64 files/s]
# Copying files: 1796 files [00:21, 99.95 files/s]
# Copying files: 1806 files [00:22, 99.69 files/s]
# Copying files: 1817 files [00:22, 100.38 files/s]
# Copying files: 1828 files [00:22, 99.72 files/s]
# Copying files: 1838 files [00:22, 99.25 files/s]
# Copying files: 1849 files [00:22, 101.50 files/s]
# Copying files: 1860 files [00:22, 101.89 files/s]
# Copying files: 1871 files [00:22, 102.48 files/s]
# Copying files: 1882 files [00:22, 102.02 files/s]
# Copying files: 1893 files [00:22, 103.14 files/s]
# Copying files: 1904 files [00:23, 102.75 files/s]
# Copying files: 1915 files [00:23, 103.36 files/s]
# Copying files: 1926 files [00:23, 103.51 files/s]
# Copying files: 1937 files [00:23, 101.31 files/s]
# Copying files: 1948 files [00:23, 101.77 files/s]
# Copying files: 1959 files [00:23, 101.82 files/s]
# Copying files: 1970 files [00:23, 98.83 files/s]
# Copying files: 1980 files [00:23, 97.00 files/s]
# Copying files: 1990 files [00:23, 97.59 files/s]
# Copying files: 2001 files [00:24, 99.72 files/s]
# Copying files: 2012 files [00:24, 100.95 files/s]
# Copying files: 2023 files [00:24, 100.94 files/s]
# Copying files: 2034 files [00:24, 102.09 files/s]
# Copying files: 2045 files [00:24, 102.32 files/s]
# Copying files: 2056 files [00:24, 102.49 files/s]
# Copying files: 2067 files [00:24, 101.46 files/s]
# Copying files: 2078 files [00:24, 101.60 files/s]
# Copying files: 2089 files [00:24, 100.30 files/s]
# Copying files: 2100 files [00:25, 98.08 files/s]
# Copying files: 2110 files [00:25, 97.81 files/s]
# Copying files: 2121 files [00:25, 100.13 files/s]
# Copying files: 2132 files [00:25, 100.67 files/s]
# Copying files: 2143 files [00:25, 101.32 files/s]
# Copying files: 2154 files [00:25, 99.83 files/s]
# Copying files: 2165 files [00:25, 101.01 files/s]
# Copying files: 2176 files [00:25, 99.35 files/s]
# Copying files: 2186 files [00:25, 95.03 files/s]
# Copying files: 2196 files [00:25, 94.85 files/s]
# Copying files: 2206 files [00:26, 89.09 files/s]
# Copying files: 2215 files [00:26, 85.43 files/s]
# Copying files: 2224 files [00:26, 77.50 files/s]
# Copying files: 2234 files [00:26, 81.80 files/s]
# Copying files: 2243 files [00:26, 83.76 files/s]
# Copying files: 2253 files [00:26, 87.50 files/s]
# Copying files: 2262 files [00:26, 78.37 files/s]
# Copying files: 2271 files [00:26, 73.71 files/s]
# Copying files: 2280 files [00:27, 77.06 files/s]
# Copying files: 2291 files [00:27, 85.31 files/s]
# Copying files: 2302 files [00:27, 90.09 files/s]
# Copying files: 2312 files [00:27, 92.58 files/s]
# Copying files: 2322 files [00:27, 94.43 files/s]
# Copying files: 2332 files [00:27, 94.68 files/s]
# Copying files: 2343 files [00:27, 97.15 files/s]
# Copying files: 2353 files [00:27, 96.06 files/s]
# Copying files: 2364 files [00:27, 97.83 files/s]
# Copying files: 2375 files [00:28, 98.79 files/s]
# Copying files: 2386 files [00:28, 99.73 files/s]
# Copying files: 2397 files [00:28, 101.80 files/s]
# Copying files: 2408 files [00:28, 103.29 files/s]
# Copying files: 2419 files [00:28, 104.04 files/s]
# Copying files: 2430 files [00:28, 104.58 files/s]
# Copying files: 2441 files [00:28, 105.26 files/s]
# Copying files: 2452 files [00:28, 105.73 files/s]
# Copying files: 2463 files [00:28, 105.76 files/s]
# Copying files: 2474 files [00:28, 105.18 files/s]
# Copying files: 2486 files [00:29, 107.02 files/s]
# Copying files: 2497 files [00:29, 104.29 files/s]
# Copying files: 2508 files [00:29, 102.15 files/s]
# Copying files: 2519 files [00:29, 98.02 files/s]
# Copying files: 2529 files [00:29, 88.39 files/s]
# Copying files: 2539 files [00:29, 88.22 files/s]
# Copying files: 2550 files [00:29, 92.28 files/s]
# Copying files: 2561 files [00:29, 94.78 files/s]
# Copying files: 2572 files [00:29, 97.37 files/s]
# Copying files: 2583 files [00:30, 99.24 files/s]
# Copying files: 2594 files [00:30, 99.76 files/s]
# Copying files: 2605 files [00:30, 100.68 files/s]
# Copying files: 2616 files [00:30, 100.77 files/s]
# Copying files: 2627 files [00:30, 99.46 files/s]
# Copying files: 2638 files [00:30, 99.37 files/s]
# Copying files: 2648 files [00:30, 98.74 files/s]
# Copying files: 2659 files [00:30, 99.69 files/s]
# Copying files: 2670 files [00:30, 100.91 files/s]
# Copying files: 2681 files [00:31, 99.28 files/s]
# Copying files: 2692 files [00:31, 100.61 files/s]
# Copying files: 2703 files [00:31, 100.17 files/s]
# Copying files: 2714 files [00:31, 101.53 files/s]
# Copying files: 2725 files [00:31, 102.19 files/s]
# Copying files: 2736 files [00:31, 102.97 files/s]
# Copying files: 2748 files [00:31, 106.65 files/s]
# Copying files: 2759 files [00:31, 105.50 files/s]
# Copying files: 2770 files [00:31, 103.25 files/s]
# Copying files: 2781 files [00:32, 99.53 files/s]
# Copying files: 2791 files [00:32, 92.97 files/s]
# Copying files: 2801 files [00:32, 82.81 files/s]
# Copying files: 2811 files [00:32, 86.72 files/s]
# Copying files: 2822 files [00:32, 91.42 files/s]
# Copying files: 2833 files [00:32, 94.92 files/s]
# Copying files: 2843 files [00:32, 95.55 files/s]
# Copying files: 2854 files [00:32, 97.96 files/s]
# Copying files: 2864 files [00:32, 97.98 files/s]
# Copying files: 2875 files [00:33, 100.01 files/s]
# Copying files: 2886 files [00:33, 100.59 files/s]
# Copying files: 2897 files [00:33, 101.27 files/s]
# Copying files: 2908 files [00:33, 103.20 files/s]
# Copying files: 2919 files [00:33, 104.28 files/s]
# Copying files: 2930 files [00:33, 104.44 files/s]
# Copying files: 2941 files [00:33, 103.96 files/s]
# Copying files: 2952 files [00:33, 103.93 files/s]
# Copying files: 2963 files [00:33, 103.90 files/s]
# Copying files: 2974 files [00:34, 105.07 files/s]
# Copying files: 2985 files [00:34, 105.91 files/s]
# Copying files: 2996 files [00:34, 104.08 files/s]
# Copying files: 3007 files [00:34, 105.20 files/s]
# Copying files: 3019 files [00:34, 106.73 files/s]
# Copying files: 3030 files [00:34, 106.16 files/s]
# Copying files: 3041 files [00:34, 106.07 files/s]
# Copying files: 3052 files [00:34, 105.39 files/s]
# Copying files: 3063 files [00:34, 105.83 files/s]
# Copying files: 3074 files [00:34, 106.13 files/s]
# Copying files: 3085 files [00:35, 106.04 files/s]
# Copying files: 3097 files [00:35, 107.62 files/s]
# Copying files: 3108 files [00:35, 104.40 files/s]
# Copying files: 3119 files [00:35, 100.03 files/s]
# Copying files: 3130 files [00:35, 88.99 files/s]
# Copying files: 3140 files [00:35, 81.98 files/s]
# Copying files: 3151 files [00:35, 86.96 files/s]
# Copying files: 3162 files [00:35, 91.69 files/s]
# Copying files: 3172 files [00:36, 92.68 files/s]
# Copying files: 3182 files [00:36, 94.18 files/s]
# Copying files: 3193 files [00:36, 96.19 files/s]
# Copying files: 3204 files [00:36, 98.42 files/s]
# Copying files: 3215 files [00:36, 99.46 files/s]
# Copying files: 3226 files [00:36, 99.92 files/s]
# Copying files: 3237 files [00:36, 100.79 files/s]
# Copying files: 3248 files [00:36, 100.85 files/s]
# Copying files: 3259 files [00:36, 96.37 files/s]
# Copying files: 3269 files [00:37, 93.78 files/s]
# Copying files: 3279 files [00:37, 91.98 files/s]
# Copying files: 3289 files [00:37, 92.67 files/s]
# Copying files: 3299 files [00:37, 91.18 files/s]
# Copying files: 3309 files [00:37, 90.87 files/s]
# Copying files: 3319 files [00:37, 89.93 files/s]
# Copying files: 3329 files [00:37, 89.04 files/s]
# Copying files: 3339 files [00:37, 89.13 files/s]
# Copying files: 3349 files [00:37, 91.38 files/s]
# Copying files: 3359 files [00:37, 93.29 files/s]
# Copying files: 3369 files [00:38, 94.95 files/s]
# Copying files: 3380 files [00:38, 97.62 files/s]
# Copying files: 3391 files [00:38, 100.06 files/s]
# Copying files: 3402 files [00:38, 101.20 files/s]
# Copying files: 3413 files [00:38, 101.70 files/s]
# Copying files: 3424 files [00:38, 102.06 files/s]
# Copying files: 3435 files [00:38, 103.17 files/s]
# Copying files: 3446 files [00:38, 103.08 files/s]
# Copying files: 3457 files [00:38, 104.49 files/s]
# Copying files: 3468 files [00:39, 105.19 files/s]
# Copying files: 3479 files [00:39, 103.60 files/s]
# Copying files: 3490 files [00:39, 104.26 files/s]
# Copying files: 3501 files [00:39, 104.13 files/s]
# Copying files: 3512 files [00:39, 104.64 files/s]
# Copying files: 3523 files [00:39, 104.69 files/s]
# Copying files: 3534 files [00:39, 102.97 files/s]
# Copying files: 3545 files [00:39, 102.65 files/s]
# Copying files: 3556 files [00:39, 103.58 files/s]
# Copying files: 3567 files [00:40, 102.50 files/s]
# Copying files: 3578 files [00:40, 100.37 files/s]
# Copying files: 3589 files [00:40, 100.27 files/s]
# Copying files: 3600 files [00:40, 101.88 files/s]
# Copying files: 3611 files [00:40, 103.03 files/s]
# Copying files: 3622 files [00:40, 103.27 files/s]
# Copying files: 3633 files [00:40, 102.86 files/s]
# Copying files: 3644 files [00:40, 102.58 files/s]
# Copying files: 3655 files [00:40, 102.95 files/s]
# Copying files: 3666 files [00:40, 103.80 files/s]
# Copying files: 3677 files [00:41, 103.81 files/s]
# Copying files: 3688 files [00:41, 102.37 files/s]
# Copying files: 3699 files [00:41, 102.52 files/s]
# Copying files: 3710 files [00:41, 102.62 files/s]
# Copying files: 3721 files [00:41, 102.12 files/s]
# Copying files: 3732 files [00:41, 102.92 files/s]
# Copying files: 3743 files [00:41, 102.62 files/s]
# Copying files: 3754 files [00:41, 102.69 files/s]
# Copying files: 3765 files [00:41, 103.32 files/s]
# Copying files: 3776 files [00:42, 103.48 files/s]
# Copying files: 3787 files [00:42, 102.14 files/s]
# Copying files: 3798 files [00:42, 102.07 files/s]
# Copying files: 3809 files [00:42, 101.74 files/s]
# Copying files: 3820 files [00:42, 102.65 files/s]
# Copying files: 3831 files [00:42, 102.14 files/s]
# Copying files: 3842 files [00:42, 102.64 files/s]
# Copying files: 3853 files [00:42, 100.46 files/s]
# Copying files: 3864 files [00:42, 100.62 files/s]
# Copying files: 3875 files [00:43, 101.56 files/s]
# Copying files: 3886 files [00:43, 101.39 files/s]
# Copying files: 3897 files [00:43, 101.26 files/s]
# Copying files: 3908 files [00:43, 101.18 files/s]
# Copying files: 3919 files [00:43, 101.68 files/s]
# Copying files: 3930 files [00:43, 101.47 files/s]
# Copying files: 3941 files [00:43, 103.32 files/s]
# Copying files: 3952 files [00:43, 103.77 files/s]
# Copying files: 3963 files [00:43, 103.20 files/s]
# Copying files: 3974 files [00:43, 103.68 files/s]
# Copying files: 3985 files [00:44, 104.32 files/s]
# Copying files: 3996 files [00:44, 105.37 files/s]
# Copying files: 4007 files [00:44, 105.51 files/s]
# Copying files: 4018 files [00:44, 104.70 files/s]
# Copying files: 4029 files [00:44, 104.44 files/s]
# Copying files: 4040 files [00:44, 105.16 files/s]
# Copying files: 4051 files [00:44, 104.46 files/s]
# Copying files: 4062 files [00:44, 105.17 files/s]
# Copying files: 4073 files [00:44, 105.07 files/s]
# Copying files: 4084 files [00:45, 105.29 files/s]
# Copying files: 4095 files [00:45, 105.15 files/s]
# Copying files: 4106 files [00:45, 105.36 files/s]
# Copying files: 4117 files [00:45, 106.11 files/s]
# Copying files: 4128 files [00:45, 104.52 files/s]
# Copying files: 4139 files [00:45, 104.31 files/s]
# Copying files: 4150 files [00:45, 104.47 files/s]
# Copying files: 4161 files [00:45, 105.17 files/s]
# Copying files: 4172 files [00:45, 104.47 files/s]
# Copying files: 4183 files [00:45, 104.28 files/s]
# Copying files: 4194 files [00:46, 104.15 files/s]
# Copying files: 4205 files [00:46, 104.95 files/s]
# Copying files: 4216 files [00:46, 104.91 files/s]
# Copying files: 4227 files [00:46, 103.70 files/s]
# Copying files: 4238 files [00:46, 104.93 files/s]
# Copying files: 4250 files [00:46, 106.54 files/s]
# Copying files: 4262 files [00:46, 107.65 files/s]
# Copying files: 4273 files [00:46, 107.11 files/s]
# Copying files: 4284 files [00:46, 105.53 files/s]
# Copying files: 4295 files [00:47, 105.92 files/s]
# Copying files: 4306 files [00:47, 105.00 files/s]
# Copying files: 4317 files [00:47, 105.25 files/s]
# Copying files: 4328 files [00:47, 106.03 files/s]
# Copying files: 4339 files [00:47, 104.76 files/s]
# Copying files: 4350 files [00:47, 105.08 files/s]
# Copying files: 4361 files [00:47, 105.31 files/s]
# Copying files: 4372 files [00:47, 103.97 files/s]
# Copying files: 4383 files [00:47, 105.12 files/s]
# Copying files: 4394 files [00:47, 105.03 files/s]
# Copying files: 4405 files [00:48, 105.27 files/s]
# Copying files: 4416 files [00:48, 105.14 files/s]
# Copying files: 4428 files [00:48, 107.60 files/s]
# Copying files: 4439 files [00:48, 105.27 files/s]
# Copying files: 4450 files [00:48, 103.96 files/s]
# Copying files: 4461 files [00:48, 102.77 files/s]
# Copying files: 4472 files [00:48, 104.25 files/s]
# Copying files: 4483 files [00:48, 104.42 files/s]
# Copying files: 4494 files [00:48, 104.54 files/s]
# Copying files: 4505 files [00:49, 103.74 files/s]
# Copying files: 4516 files [00:49, 104.96 files/s]
# Copying files: 4527 files [00:49, 104.92 files/s]
# Copying files: 4538 files [00:49, 104.89 files/s]
# Copying files: 4549 files [00:49, 105.78 files/s]
# Copying files: 4560 files [00:49, 102.83 files/s]
# Copying files: 4571 files [00:49, 102.84 files/s]
# Copying files: 4582 files [00:49, 104.02 files/s]
# Copying files: 4593 files [00:49, 105.46 files/s]
# Copying files: 4604 files [00:49, 106.18 files/s]
# Copying files: 4615 files [00:50, 104.27 files/s]
# Copying files: 4626 files [00:50, 105.64 files/s]
# Copying files: 4637 files [00:50, 105.39 files/s]
# Copying files: 4648 files [00:50, 105.22 files/s]
# Copying files: 4659 files [00:50, 106.32 files/s]
# Copying files: 4670 files [00:50, 104.96 files/s]
# Copying files: 4681 files [00:50, 104.32 files/s]
# Copying files: 4692 files [00:50, 105.07 files/s]
# Copying files: 4703 files [00:50, 103.81 files/s]
# Copying files: 4714 files [00:51, 102.94 files/s]
# Copying files: 4725 files [00:51, 103.79 files/s]
# Copying files: 4736 files [00:51, 104.10 files/s]
# Copying files: 4747 files [00:51, 104.02 files/s]
# Copying files: 4758 files [00:51, 103.38 files/s]
# Copying files: 4769 files [00:51, 102.65 files/s]
# Copying files: 4780 files [00:51, 102.71 files/s]
# Copying files: 4791 files [00:51, 102.47 files/s]
# Copying files: 4802 files [00:51, 103.46 files/s]
# Copying files: 4813 files [00:51, 103.28 files/s]
# Copying files: 4824 files [00:52, 103.74 files/s]
# Copying files: 4835 files [00:52, 103.77 files/s]
# Copying files: 4846 files [00:52, 104.68 files/s]
# Copying files: 4857 files [00:52, 105.63 files/s]
# Copying files: 4869 files [00:52, 108.57 files/s]
# Copying files: 4880 files [00:52, 108.06 files/s]
# Copying files: 4891 files [00:52, 105.26 files/s]
# Copying files: 4902 files [00:52, 104.25 files/s]
# Copying files: 4914 files [00:52, 106.64 files/s]
# Copying files: 4925 files [00:53, 104.63 files/s]
# Copying files: 4936 files [00:53, 103.81 files/s]
# Copying files: 4947 files [00:53, 104.40 files/s]
# Copying files: 4958 files [00:53, 105.72 files/s]
# Copying files: 4969 files [00:53, 106.06 files/s]
# Copying files: 4980 files [00:53, 105.99 files/s]
# Copying files: 4991 files [00:53, 103.56 files/s]
# Copying files: 5002 files [00:53, 103.35 files/s]
# Copying files: 5013 files [00:53, 103.50 files/s]
# Copying files: 5024 files [00:54, 103.60 files/s]
# Copying files: 5035 files [00:54, 104.26 files/s]
# Copying files: 5046 files [00:54, 103.54 files/s]
# Copying files: 5057 files [00:54, 103.93 files/s]
# Copying files: 5068 files [00:54, 105.39 files/s]
# Copying files: 5080 files [00:54, 107.15 files/s]
# Copying files: 5091 files [00:54, 106.44 files/s]
# Copying files: 5102 files [00:54, 105.06 files/s]
# Copying files: 5113 files [00:54, 106.19 files/s]
# Copying files: 5124 files [00:54, 105.48 files/s]
# Copying files: 5135 files [00:55, 104.09 files/s]
# Copying files: 5146 files [00:55, 103.14 files/s]
# Copying files: 5157 files [00:55, 102.49 files/s]
# Copying files: 5168 files [00:55, 103.47 files/s]
# Copying files: 5179 files [00:55, 104.46 files/s]
# Copying files: 5190 files [00:55, 104.57 files/s]
# Copying files: 5201 files [00:55, 104.05 files/s]
# Copying files: 5212 files [00:55, 102.82 files/s]
# Copying files: 5223 files [00:55, 103.71 files/s]
# Copying files: 5234 files [00:56, 104.04 files/s]
# Copying files: 5245 files [00:56, 104.57 files/s]
# Copying files: 5256 files [00:56, 103.47 files/s]
# Copying files: 5267 files [00:56, 103.00 files/s]
# Copying files: 5278 files [00:56, 100.97 files/s]
# Copying files: 5289 files [00:56, 101.82 files/s]
# Copying files: 5300 files [00:56, 103.57 files/s]
# Copying files: 5311 files [00:56, 104.54 files/s]
# Copying files: 5322 files [00:56, 104.33 files/s]
# Copying files: 5333 files [00:56, 105.68 files/s]
# Copying files: 5344 files [00:57, 105.12 files/s]
# Copying files: 5355 files [00:57, 105.94 files/s]
# Copying files: 5366 files [00:57, 104.70 files/s]
# Copying files: 5377 files [00:57, 103.85 files/s]
# Copying files: 5388 files [00:57, 104.14 files/s]
# Copying files: 5399 files [00:57, 104.05 files/s]
# Copying files: 5410 files [00:57, 103.10 files/s]
# Copying files: 5421 files [00:57, 102.16 files/s]
# Copying files: 5432 files [00:57, 103.53 files/s]
# Copying files: 5443 files [00:58, 104.21 files/s]
# Copying files: 5454 files [00:58, 103.51 files/s]
# Copying files: 5465 files [00:58, 104.20 files/s]
# Copying files: 5476 files [00:58, 103.79 files/s]
# Copying files: 5487 files [00:58, 105.00 files/s]
# Copying files: 5499 files [00:58, 106.59 files/s]
# Copying files: 5510 files [00:58, 106.36 files/s]
# Copying files: 5521 files [00:58, 105.30 files/s]
# Copying files: 5532 files [00:58, 105.46 files/s]
# Copying files: 5543 files [00:58, 104.97 files/s]
# Copying files: 5554 files [00:59, 104.91 files/s]
# Copying files: 5565 files [00:59, 103.98 files/s]
# Copying files: 5576 files [00:59, 105.43 files/s]
# Copying files: 5587 files [00:59, 104.35 files/s]
# Copying files: 5598 files [00:59, 105.08 files/s]
# Copying files: 5609 files [00:59, 105.30 files/s]
# Copying files: 5620 files [00:59, 106.38 files/s]
# Copying files: 5631 files [00:59, 106.52 files/s]
# Copying files: 5642 files [00:59, 106.01 files/s]
# Copying files: 5653 files [01:00, 106.57 files/s]
# Copying files: 5664 files [01:00, 106.04 files/s]
# Copying files: 5675 files [01:00, 106.91 files/s]
# Copying files: 5686 files [01:00, 106.27 files/s]
# Copying files: 5697 files [01:00, 104.93 files/s]
# Copying files: 5708 files [01:00, 103.42 files/s]
# Copying files: 5719 files [01:00, 105.03 files/s]
# Copying files: 5730 files [01:00, 105.57 files/s]
# Copying files: 5742 files [01:00, 106.09 files/s]
# Copying files: 5753 files [01:00, 104.82 files/s]
# Copying files: 5764 files [01:01, 104.24 files/s]
# Copying files: 5775 files [01:01, 104.41 files/s]
# Copying files: 5786 files [01:01, 105.73 files/s]
# Copying files: 5797 files [01:01, 105.46 files/s]
# Copying files: 5808 files [01:01, 104.37 files/s]
# Copying files: 5819 files [01:01, 104.81 files/s]
# Copying files: 5830 files [01:01, 105.11 files/s]
# Copying files: 5841 files [01:01, 104.43 files/s]
# Copying files: 5852 files [01:01, 103.37 files/s]
# Copying files: 5863 files [01:02, 99.85 files/s]
# Copying files: 5874 files [01:02, 100.46 files/s]
# Copying files: 5885 files [01:02, 102.01 files/s]
# Copying files: 5896 files [01:02, 103.71 files/s]
# Copying files: 5907 files [01:02, 103.46 files/s]
# Copying files: 5918 files [01:02, 104.16 files/s]
# Copying files: 5929 files [01:02, 104.66 files/s]
# Copying files: 5940 files [01:02, 105.92 files/s]
# Copying files: 5951 files [01:02, 105.89 files/s]
# Copying files: 5962 files [01:02, 104.67 files/s]
# Copying files: 5973 files [01:03, 104.71 files/s]
# Copying files: 5984 files [01:03, 105.35 files/s]
# Copying files: 5995 files [01:03, 103.41 files/s]
# Copying files: 6006 files [01:03, 103.25 files/s]
# Copying files: 6017 files [01:03, 101.70 files/s]
# Copying files: 6028 files [01:03, 102.62 files/s]
# Copying files: 6039 files [01:03, 102.98 files/s]
# Copying files: 6050 files [01:03, 103.53 files/s]
# Copying files: 6061 files [01:03, 103.62 files/s]
# Copying files: 6072 files [01:04, 104.28 files/s]
# Copying files: 6083 files [01:04, 104.74 files/s]
# Copying files: 6095 files [01:04, 107.01 files/s]
# Copying files: 6106 files [01:04, 106.97 files/s]
# Copying files: 6117 files [01:04, 107.24 files/s]
# Copying files: 6128 files [01:04, 105.60 files/s]
# Copying files: 6139 files [01:04, 103.31 files/s]
# Copying files: 6150 files [01:04, 103.75 files/s]
# Copying files: 6161 files [01:04, 104.96 files/s]
# Copying files: 6172 files [01:04, 104.92 files/s]
# Copying files: 6183 files [01:05, 97.65 files/s]
# Copying files: 6194 files [01:05, 99.96 files/s]
# Copying files: 6205 files [01:05, 101.94 files/s]
# Copying files: 6216 files [01:05, 103.66 files/s]
# Copying files: 6227 files [01:05, 103.13 files/s]
# Copying files: 6238 files [01:05, 100.23 files/s]
# Copying files: 6249 files [01:05, 102.71 files/s]
# Copying files: 6261 files [01:05, 104.97 files/s]
# Copying files: 6272 files [01:05, 104.63 files/s]
# Copying files: 6283 files [01:06, 105.28 files/s]
# Copying files: 6294 files [01:06, 103.10 files/s]
# Copying files: 6305 files [01:06, 104.78 files/s]
# Copying files: 6316 files [01:06, 105.09 files/s]
# Copying files: 6327 files [01:06, 104.42 files/s]
# Copying files: 6338 files [01:06, 103.95 files/s]
# Copying files: 6349 files [01:06, 102.75 files/s]
# Copying files: 6361 files [01:06, 106.48 files/s]
# Copying files: 6372 files [01:06, 107.20 files/s]
# Copying files: 6383 files [01:07, 106.49 files/s]
# Copying files: 6394 files [01:07, 107.22 files/s]
# Copying files: 6405 files [01:07, 104.39 files/s]
# Copying files: 6416 files [01:07, 105.41 files/s]
# Copying files: 6427 files [01:07, 104.34 files/s]
# Copying files: 6438 files [01:07, 104.49 files/s]
# Copying files: 6449 files [01:07, 103.70 files/s]
# Copying files: 6461 files [01:07, 106.87 files/s]
# Copying files: 6472 files [01:07, 106.56 files/s]
# Copying files: 6483 files [01:07, 106.96 files/s]
# Copying files: 6494 files [01:08, 107.55 files/s]
# Copying files: 6505 files [01:08, 106.11 files/s]
# Copying files: 6516 files [01:08, 104.23 files/s]
# Copying files: 6527 files [01:08, 104.70 files/s]
# Copying files: 6538 files [01:08, 105.04 files/s]
# Copying files: 6549 files [01:08, 104.68 files/s]
# Copying files: 6560 files [01:08, 102.10 files/s]
# Copying files: 6571 files [01:08, 102.62 files/s]
# Copying files: 6582 files [01:08, 102.98 files/s]
# Copying files: 6593 files [01:09, 103.24 files/s]
# Copying files: 6604 files [01:09, 104.00 files/s]
# Copying files: 6615 files [01:09, 102.21 files/s]
# Copying files: 6626 files [01:09, 104.15 files/s]
# Copying files: 6637 files [01:09, 104.95 files/s]
# Copying files: 6648 files [01:09, 105.52 files/s]
# Copying files: 6659 files [01:09, 105.01 files/s]
# Copying files: 6670 files [01:09, 104.65 files/s]
# Copying files: 6681 files [01:09, 105.31 files/s]
# Copying files: 6692 files [01:09, 104.56 files/s]
# Copying files: 6703 files [01:10, 102.88 files/s]
# Copying files: 6714 files [01:10, 100.62 files/s]
# Copying files: 6725 files [01:10, 99.90 files/s]
# Copying files: 6736 files [01:10, 100.50 files/s]
# Copying files: 6747 files [01:10, 100.92 files/s]
# Copying files: 6758 files [01:10, 102.92 files/s]
# Copying files: 6769 files [01:10, 102.62 files/s]
# Copying files: 6780 files [01:10, 102.69 files/s]
# Copying files: 6791 files [01:10, 103.32 files/s]
# Copying files: 6802 files [01:11, 103.18 files/s]
# Copying files: 6813 files [01:11, 103.07 files/s]
# Copying files: 6824 files [01:11, 100.75 files/s]
# Copying files: 6835 files [01:11, 100.54 files/s]
# Copying files: 6846 files [01:11, 99.58 files/s]
# Copying files: 6857 files [01:11, 100.82 files/s]
# Copying files: 6868 files [01:11, 101.42 files/s]
# Copying files: 6879 files [01:11, 100.44 files/s]
# Copying files: 6890 files [01:11, 102.57 files/s]
# Copying files: 6901 files [01:12, 102.37 files/s]
# Copying files: 6912 files [01:12, 103.10 files/s]
# Copying files: 6923 files [01:12, 103.03 files/s]
# Copying files: 6934 files [01:12, 101.27 files/s]
# Copying files: 6945 files [01:12, 100.91 files/s]
# Copying files: 6956 files [01:12, 101.77 files/s]
# Copying files: 6967 files [01:12, 102.38 files/s]
# Copying files: 6978 files [01:12, 100.01 files/s]
# Copying files: 6989 files [01:12, 99.21 files/s]
# Copying files: 7000 files [01:13, 100.56 files/s]
# Copying files: 7011 files [01:13, 101.52 files/s]
# Copying files: 7022 files [01:13, 101.92 files/s]
# Copying files: 7033 files [01:13, 100.80 files/s]
# Copying files: 7044 files [01:13, 101.13 files/s]
# Copying files: 7055 files [01:13, 101.65 files/s]
# Copying files: 7066 files [01:13, 102.29 files/s]
# Copying files: 7077 files [01:13, 103.33 files/s]
# Copying files: 7088 files [01:13, 101.76 files/s]
# Copying files: 7099 files [01:13, 101.81 files/s]
# Copying files: 7110 files [01:14, 100.72 files/s]
# Copying files: 7121 files [01:14, 100.80 files/s]
# Copying files: 7132 files [01:14, 100.56 files/s]
# Copying files: 7143 files [01:14, 99.87 files/s]
# Copying files: 7154 files [01:14, 99.92 files/s]
# Copying files: 7165 files [01:14, 100.79 files/s]
# Copying files: 7176 files [01:14, 102.25 files/s]
# Copying files: 7187 files [01:14, 102.72 files/s]
# Copying files: 7198 files [01:14, 101.90 files/s]
# Copying files: 7209 files [01:15, 101.91 files/s]
# Copying files: 7220 files [01:15, 103.64 files/s]
# Copying files: 7231 files [01:15, 103.11 files/s]
# Copying files: 7242 files [01:15, 102.46 files/s]
# Copying files: 7253 files [01:15, 100.34 files/s]
# Copying files: 7264 files [01:15, 101.36 files/s]
# Copying files: 7275 files [01:15, 101.81 files/s]
# Copying files: 7286 files [01:15, 102.70 files/s]
# Copying files: 7297 files [01:15, 101.61 files/s]
# Copying files: 7308 files [01:16, 100.59 files/s]
# Copying files: 7319 files [01:16, 102.11 files/s]
# Copying files: 7330 files [01:16, 102.33 files/s]
# Copying files: 7341 files [01:16, 101.92 files/s]
# Copying files: 7352 files [01:16, 101.36 files/s]
# Copying files: 7363 files [01:16, 101.80 files/s]
# Copying files: 7374 files [01:16, 102.69 files/s]
# Copying files: 7385 files [01:16, 102.17 files/s]
# Copying files: 7396 files [01:16, 100.14 files/s]
# Copying files: 7407 files [01:17, 99.58 files/s]
# Copying files: 7418 files [01:17, 100.82 files/s]
# Copying files: 7429 files [01:17, 101.14 files/s]
# Copying files: 7440 files [01:17, 101.65 files/s]
# Copying files: 7451 files [01:17, 101.73 files/s]
# Copying files: 7462 files [01:17, 99.31 files/s]
# Copying files: 7473 files [01:17, 100.08 files/s]
# Copying files: 7484 files [01:17, 99.80 files/s]
# Copying files: 7494 files [01:17, 99.32 files/s]
# Copying files: 7504 files [01:17, 98.96 files/s]
# Copying files: 7515 files [01:18, 99.86 files/s]
# Copying files: 7526 files [01:18, 100.48 files/s]
# Copying files: 7537 files [01:18, 100.63 files/s]
# Copying files: 7548 files [01:18, 100.74 files/s]
# Copying files: 7559 files [01:18, 100.81 files/s]
# Copying files: 7570 files [01:18, 102.56 files/s]
# Copying files: 7581 files [01:18, 103.82 files/s]
# Copying files: 7592 files [01:18, 104.12 files/s]
# Copying files: 7603 files [01:18, 104.33 files/s]
# Copying files: 7614 files [01:19, 103.01 files/s]
# Copying files: 7625 files [01:19, 103.84 files/s]
# Copying files: 7636 files [01:19, 105.33 files/s]
# Copying files: 7647 files [01:19, 105.79 files/s]
# Copying files: 7658 files [01:19, 106.11 files/s]
# Copying files: 7669 files [01:19, 103.34 files/s]
# Copying files: 7680 files [01:19, 103.49 files/s]
# Copying files: 7691 files [01:19, 103.59 files/s]
# Copying files: 7702 files [01:19, 103.67 files/s]
# Copying files: 7713 files [01:20, 102.84 files/s]
# Copying files: 7724 files [01:20, 103.72 files/s]
# Copying files: 7735 files [01:20, 104.35 files/s]
# Copying files: 7746 files [01:20, 104.19 files/s]
# Copying files: 7757 files [01:20, 104.68 files/s]
# Copying files: 7768 files [01:20, 104.13 files/s]
# Copying files: 7779 files [01:20, 104.04 files/s]
# Copying files: 7790 files [01:20, 104.87 files/s]
# Copying files: 7801 files [01:20, 105.16 files/s]
# Copying files: 7812 files [01:20, 102.99 files/s]
# Copying files: 7823 files [01:21, 102.67 files/s]
# Copying files: 7834 files [01:21, 100.48 files/s]
# Copying files: 7845 files [01:21, 101.46 files/s]
# Copying files: 7856 files [01:21, 102.45 files/s]
# Copying files: 7867 files [01:21, 103.15 files/s]
# Copying files: 7878 files [01:21, 102.78 files/s]
# Copying files: 7889 files [01:21, 103.97 files/s]
# Copying files: 7900 files [01:21, 105.12 files/s]
# Copying files: 7911 files [01:21, 106.25 files/s]
# Copying files: 7922 files [01:22, 105.51 files/s]
# Copying files: 7933 files [01:22, 104.71 files/s]
# Copying files: 7944 files [01:22, 103.56 files/s]
# Copying files: 7955 files [01:22, 101.91 files/s]
# Copying files: 7966 files [01:22, 102.77 files/s]
# Copying files: 7977 files [01:22, 103.09 files/s]
# Copying files: 7988 files [01:22, 100.76 files/s]
# Copying files: 7999 files [01:22, 101.95 files/s]
# Copying files: 8010 files [01:22, 103.08 files/s]
# Copying files: 8021 files [01:22, 102.44 files/s]
# Copying files: 8032 files [01:23, 103.15 files/s]
# Copying files: 8043 files [01:23, 102.20 files/s]
# Copying files: 8054 files [01:23, 102.40 files/s]
# Copying files: 8065 files [01:23, 102.54 files/s]
# Copying files: 8076 files [01:23, 102.93 files/s]
# Copying files: 8087 files [01:23, 100.37 files/s]
# Copying files: 8098 files [01:23, 99.20 files/s]
# Copying files: 8109 files [01:23, 100.82 files/s]
# Copying files: 8120 files [01:23, 102.27 files/s]
# Copying files: 8131 files [01:24, 103.61 files/s]
# Copying files: 8142 files [01:24, 103.38 files/s]
# Copying files: 8153 files [01:24, 104.70 files/s]
# Copying files: 8164 files [01:24, 105.34 files/s]
# Copying files: 8175 files [01:24, 104.59 files/s]
# Copying files: 8186 files [01:24, 105.56 files/s]
# Copying files: 8197 files [01:24, 103.85 files/s]
# Copying files: 8208 files [01:24, 104.73 files/s]
# Copying files: 8219 files [01:24, 105.06 files/s]
# Copying files: 8230 files [01:25, 102.64 files/s]
# Copying files: 8241 files [01:25, 103.29 files/s]
# Copying files: 8252 files [01:25, 102.87 files/s]
# Copying files: 8263 files [01:25, 103.16 files/s]
# Copying files: 8274 files [01:25, 104.24 files/s]
# Copying files: 8285 files [01:25, 104.12 files/s]
# Copying files: 8296 files [01:25, 103.45 files/s]
# Copying files: 8307 files [01:25, 102.41 files/s]
# Copying files: 8318 files [01:26, 62.27 files/s]
# Copying files: 8327 files [01:26, 67.43 files/s]
# Copying files: 8336 files [01:26, 70.21 files/s]
# Copying files: 8347 files [01:26, 77.46 files/s]
# Copying files: 8357 files [01:26, 82.37 files/s]
# Copying files: 8368 files [01:26, 89.03 files/s]
# Copying files: 8378 files [01:26, 90.53 files/s]
# Copying files: 8388 files [01:26, 91.88 files/s]
# Copying files: 8399 files [01:26, 95.09 files/s]
# Copying files: 8411 files [01:27, 100.13 files/s]
# Copying files: 8422 files [01:27, 100.11 files/s]
# Copying files: 8433 files [01:27, 100.64 files/s]
# Copying files: 8444 files [01:27, 99.92 files/s]
# Copying files: 8455 files [01:27, 100.51 files/s]
# Copying files: 8466 files [01:27, 101.49 files/s]
# Copying files: 8477 files [01:27, 101.62 files/s]
# Copying files: 8488 files [01:27, 98.69 files/s]
# Copying files: 8499 files [01:27, 99.37 files/s]
# Copying files: 8510 files [01:28, 100.12 files/s]
# Copying files: 8521 files [01:28, 101.21 files/s]
# Copying files: 8532 files [01:28, 102.27 files/s]
# Copying files: 8543 files [01:28, 100.76 files/s]
# Copying files: 8554 files [01:28, 101.38 files/s]
# Copying files: 8565 files [01:28, 102.11 files/s]
# Copying files: 8576 files [01:28, 103.78 files/s]
# Copying files: 8587 files [01:28, 103.80 files/s]
# Copying files: 8598 files [01:28, 101.51 files/s]
# Copying files: 8609 files [01:29, 102.20 files/s]
# Copying files: 8620 files [01:29, 100.44 files/s]
# Copying files: 8631 files [01:29, 101.71 files/s]
# Copying files: 8642 files [01:29, 101.77 files/s]
# Copying files: 8653 files [01:29, 101.25 files/s]
# Copying files: 8664 files [01:29, 101.73 files/s]
# Copying files: 8675 files [01:29, 100.67 files/s]
# Copying files: 8686 files [01:29, 101.60 files/s]
# Copying files: 8697 files [01:29, 100.30 files/s]
# Copying files: 8708 files [01:29, 100.78 files/s]
# Copying files: 8719 files [01:30, 101.68 files/s]
# Copying files: 8730 files [01:30, 100.63 files/s]
# Copying files: 8741 files [01:30, 101.57 files/s]
# Copying files: 8752 files [01:30, 99.20 files/s]
# Copying files: 8763 files [01:30, 100.00 files/s]
# Copying files: 8774 files [01:30, 100.29 files/s]
# Copying files: 8785 files [01:30, 99.95 files/s]
# Copying files: 8796 files [01:30, 99.98 files/s]
# Copying files: 8807 files [01:30, 99.73 files/s]
# Copying files: 8818 files [01:31, 101.21 files/s]
# Copying files: 8829 files [01:31, 101.70 files/s]
# Copying files: 8840 files [01:31, 101.76 files/s]
# Copying files: 8851 files [01:31, 95.70 files/s]
# Copying files: 8861 files [01:31, 91.66 files/s]
# Copying files: 8871 files [01:31, 89.36 files/s]
# Copying files: 8882 files [01:31, 92.89 files/s]
# Copying files: 8892 files [01:31, 94.33 files/s]
# Copying files: 8902 files [01:31, 95.13 files/s]
# Copying files: 8912 files [01:32, 96.25 files/s]
# Copying files: 8923 files [01:32, 98.80 files/s]
# Copying files: 8934 files [01:32, 100.03 files/s]
# Copying files: 8945 files [01:32, 100.32 files/s]
# Copying files: 8956 files [01:32, 99.41 files/s]
# Copying files: 8966 files [01:32, 98.21 files/s]
# Copying files: 8977 files [01:32, 99.32 files/s]
# Copying files: 8988 files [01:32, 100.10 files/s]
# Copying files: 8999 files [01:32, 100.37 files/s]
# Copying files: 9010 files [01:33, 99.72 files/s]
# Copying files: 9021 files [01:33, 100.10 files/s]
# Copying files: 9032 files [01:33, 99.54 files/s]
# Copying files: 9043 files [01:33, 100.80 files/s]
# Copying files: 9054 files [01:33, 99.21 files/s]
# Copying files: 9065 files [01:33, 99.74 files/s]
# Copying files: 9076 files [01:33, 100.66 files/s]
# Copying files: 9087 files [01:33, 101.31 files/s]
# Copying files: 9098 files [01:33, 101.77 files/s]
# Copying files: 9109 files [01:34, 102.10 files/s]
# Copying files: 9120 files [01:34, 103.19 files/s]
# Copying files: 9132 files [01:34, 105.31 files/s]
# Copying files: 9143 files [01:34, 105.47 files/s]
# Copying files: 9154 files [01:34, 105.28 files/s]
# Copying files: 9165 files [01:34, 100.30 files/s]
# Copying files: 9176 files [01:34, 101.61 files/s]
# Copying files: 9187 files [01:34, 102.26 files/s]
# Copying files: 9198 files [01:34, 101.60 files/s]
# Copying files: 9209 files [01:35, 100.58 files/s]
# Copying files: 9220 files [01:35, 101.81 files/s]
# Copying files: 9231 files [01:35, 103.57 files/s]
# Copying files: 9243 files [01:35, 105.87 files/s]
# Copying files: 9254 files [01:35, 104.97 files/s]
# Copying files: 9265 files [01:35, 103.18 files/s]
# Copying files: 9276 files [01:35, 103.96 files/s]
# Copying files: 9287 files [01:35, 104.21 files/s]
# Copying files: 9298 files [01:35, 103.81 files/s]
# Copying files: 9309 files [01:35, 103.23 files/s]
# Copying files: 9320 files [01:36, 102.26 files/s]
# Copying files: 9331 files [01:36, 103.02 files/s]
# Copying files: 9342 files [01:36, 101.83 files/s]
# Copying files: 9353 files [01:36, 101.86 files/s]
# Copying files: 9364 files [01:36, 103.02 files/s]
# Copying files: 9375 files [01:36, 101.27 files/s]
# Copying files: 9386 files [01:36, 101.46 files/s]
# Copying files: 9397 files [01:36, 102.45 files/s]
# Copying files: 9408 files [01:36, 102.57 files/s]
# Copying files: 9419 files [01:37, 102.95 files/s]
# Copying files: 9430 files [01:37, 102.64 files/s]
# Copying files: 9441 files [01:37, 98.57 files/s]
# Copying files: 9451 files [01:37, 97.10 files/s]
# Copying files: 9462 files [01:37, 100.17 files/s]
# Copying files: 9473 files [01:37, 102.11 files/s]
# Copying files: 9484 files [01:37, 102.63 files/s]
# Copying files: 9495 files [01:37, 102.41 files/s]
# Copying files: 9506 files [01:37, 102.84 files/s]
# Copying files: 9517 files [01:38, 104.02 files/s]
# Copying files: 9528 files [01:38, 103.37 files/s]
# Copying files: 9539 files [01:38, 103.22 files/s]
# Copying files: 9550 files [01:38, 104.29 files/s]
# Copying files: 9561 files [01:38, 105.05 files/s]
# Copying files: 9572 files [01:38, 105.28 files/s]
# Copying files: 9583 files [01:38, 103.95 files/s]
# Copying files: 9594 files [01:38, 100.50 files/s]
# Copying files: 9605 files [01:38, 101.76 files/s]
# Copying files: 9616 files [01:38, 102.66 files/s]
# Copying files: 9627 files [01:39, 102.44 files/s]
# Copying files: 9638 files [01:39, 99.78 files/s]
# Copying files: 9649 files [01:39, 101.52 files/s]
# Copying files: 9660 files [01:39, 103.07 files/s]
# Copying files: 9671 files [01:39, 103.59 files/s]
# Copying files: 9682 files [01:39, 103.66 files/s]
# Copying files: 9693 files [01:39, 102.55 files/s]
# Copying files: 9704 files [01:39, 102.65 files/s]
# Copying files: 9715 files [01:39, 102.43 files/s]
# Copying files: 9726 files [01:40, 101.42 files/s]
# Copying files: 9737 files [01:40, 100.46 files/s]
# Copying files: 9748 files [01:40, 98.99 files/s]
# Copying files: 9759 files [01:40, 101.22 files/s]
# Copying files: 9770 files [01:40, 102.56 files/s]
# Copying files: 9781 files [01:40, 101.52 files/s]
# Copying files: 9792 files [01:40, 101.92 files/s]
# Copying files: 9803 files [01:40, 100.52 files/s]
# Copying files: 9814 files [01:40, 100.94 files/s]
# Copying files: 9825 files [01:41, 102.36 files/s]
# Copying files: 9836 files [01:41, 103.38 files/s]
# Copying files: 9847 files [01:41, 102.36 files/s]
# Copying files: 9858 files [01:41, 101.66 files/s]
# Copying files: 9869 files [01:41, 101.74 files/s]
# Copying files: 9880 files [01:41, 101.51 files/s]
# Copying files: 9891 files [01:41, 101.91 files/s]
# Copying files: 9902 files [01:41, 100.52 files/s]
# Copying files: 9913 files [01:41, 96.17 files/s]
# Copying files: 9924 files [01:42, 98.61 files/s]
# Copying files: 9935 files [01:42, 100.40 files/s]
# Copying files: 9946 files [01:42, 100.02 files/s]
# Copying files: 9957 files [01:42, 99.22 files/s]
# Copying files: 9967 files [01:42, 99.18 files/s]
# Copying files: 9977 files [01:42, 99.15 files/s]
# Copying files: 9988 files [01:42, 100.53 files/s]
# Copying files: 9999 files [01:42, 100.37 files/s]
# Copying files: 10010 files [01:42, 98.63 files/s]
# Copying files: 10021 files [01:42, 100.15 files/s]
# Copying files: 10032 files [01:43, 100.40 files/s]
# Copying files: 10043 files [01:43, 102.55 files/s]
# Copying files: 10054 files [01:43, 102.94 files/s]
# Copying files: 10065 files [01:43, 102.34 files/s]
# Copying files: 10076 files [01:43, 102.50 files/s]
# Copying files: 10087 files [01:43, 102.90 files/s]
# Copying files: 10098 files [01:43, 103.18 files/s]
# Copying files: 10109 files [01:43, 102.51 files/s]
# Copying files: 10120 files [01:43, 102.90 files/s]
# Copying files: 10131 files [01:44, 102.32 files/s]
# Copying files: 10142 files [01:44, 101.35 files/s]
# Copying files: 10153 files [01:44, 101.24 files/s]
# Copying files: 10164 files [01:44, 100.06 files/s]
# Copying files: 10175 files [01:44, 100.61 files/s]
# Copying files: 10186 files [01:44, 102.98 files/s]
# Copying files: 10197 files [01:44, 103.24 files/s]
# Copying files: 10208 files [01:44, 102.26 files/s]
# Copying files: 10219 files [01:44, 101.31 files/s]
# Copying files: 10230 files [01:45, 101.49 files/s]
# Copying files: 10241 files [01:45, 100.78 files/s]
# Copying files: 10252 files [01:45, 101.68 files/s]
# Copying files: 10263 files [01:45, 101.19 files/s]
# Copying files: 10274 files [01:45, 98.41 files/s]
# Copying files: 10284 files [01:45, 98.60 files/s]
# Copying files: 10295 files [01:45, 99.86 files/s]
# Copying files: 10305 files [01:45, 99.64 files/s]
# Copying files: 10315 files [01:45, 99.19 files/s]
# Copying files: 10325 files [01:45, 99.15 files/s]
# Copying files: 10336 files [01:46, 100.29 files/s]
# Copying files: 10347 files [01:46, 101.37 files/s]
# Copying files: 10358 files [01:46, 101.82 files/s]
# Copying files: 10369 files [01:46, 100.71 files/s]
# ...
# Copying files: 21536 files [03:38, 99.64 files/s]
# Copying files: 21547 files [03:38, 100.59 files/s]
# Copying files: 21558 files [03:39, 101.82 files/s]
# Copying files: 21569 files [03:39, 101.85 files/s]
# Copying files: 21580 files [03:39, 102.73 files/s]
# Copying files: 21591 files [03:39, 102.77 files/s]
# Copying files: 21602 files [03:39, 101.66 files/s]
# Copying files: 21613 files [03:39, 102.88 files/s]
# Copying files: 21624 files [03:39, 104.34 files/s]
# Copying files: 21635 files [03:39, 104.78 files/s]
# Copying files: 21646 files [03:39, 103.90 files/s]
# Copying files: 21657 files [03:40, 101.58 files/s]
# Copying files: 21668 files [03:40, 100.57 files/s]
# Copying files: 21679 files [03:40, 102.66 files/s]
# Copying files: 21690 files [03:40, 103.30 files/s]
# Copying files: 21701 files [03:40, 104.94 files/s]
# Copying files: 21712 files [03:40, 104.61 files/s]
# Copying files: 21723 files [03:40, 105.58 files/s]
# Copying files: 21734 files [03:40, 106.27 files/s]
# Copying files: 21745 files [03:40, 107.07 files/s]
# Copying files: 21756 files [03:40, 107.32 files/s]
# Copying files: 21767 files [03:41, 105.64 files/s]
# Copying files: 21778 files [03:41, 106.62 files/s]
# Copying files: 21789 files [03:41, 106.69 files/s]
# Copying files: 21800 files [03:41, 105.51 files/s]
# Copying files: 21811 files [03:41, 105.31 files/s]
# Copying files: 21822 files [03:41, 104.27 files/s]
# Copying files: 21833 files [03:41, 105.64 files/s]
# Copying files: 21844 files [03:41, 106.00 files/s]
# Copying files: 21856 files [03:41, 107.29 files/s]
# Copying files: 21867 files [03:42, 104.18 files/s]
# Copying files: 21878 files [03:42, 96.01 files/s]
# Copying files: 21888 files [03:42, 92.85 files/s]
# Copying files: 21899 files [03:42, 96.19 files/s]
# Copying files: 21910 files [03:42, 99.73 files/s]
# Copying files: 21921 files [03:42, 100.38 files/s]
# Copying files: 21932 files [03:42, 98.93 files/s]
# Copying files: 21943 files [03:42, 100.63 files/s]
# Copying files: 21954 files [03:42, 102.14 files/s]
# Copying files: 21965 files [03:43, 102.36 files/s]
# Copying files: 21976 files [03:43, 101.94 files/s]
# Copying files: 21987 files [03:43, 103.66 files/s]
# Copying files: 21999 files [03:43, 105.35 files/s]
# Copying files: 22010 files [03:43, 104.32 files/s]
# Copying files: 22021 files [03:43, 103.31 files/s]
# Copying files: 22032 files [03:43, 103.46 files/s]
# Copying files: 22043 files [03:43, 104.45 files/s]
# Copying files: 22054 files [03:43, 105.16 files/s]
# Copying files: 22065 files [03:43, 104.17 files/s]
# Copying files: 22076 files [03:44, 103.48 files/s]
# Copying files: 22087 files [03:44, 101.87 files/s]
# Copying files: 22098 files [03:44, 103.02 files/s]
# Copying files: 22109 files [03:44, 103.27 files/s]
# Copying files: 22120 files [03:44, 103.73 files/s]
# Copying files: 22131 files [03:44, 102.60 files/s]
# Copying files: 22142 files [03:44, 102.39 files/s]
# Copying files: 22153 files [03:44, 103.40 files/s]
# Copying files: 22164 files [03:44, 104.42 files/s]
# Copying files: 22175 files [03:45, 104.24 files/s]
# Copying files: 22186 files [03:45, 102.95 files/s]
# Copying files: 22197 files [03:45, 104.69 files/s]
# Copying files: 22208 files [03:45, 104.43 files/s]
# Copying files: 22219 files [03:45, 101.09 files/s]
# Copying files: 22230 files [03:45, 101.06 files/s]
# Copying files: 22241 files [03:45, 101.03 files/s]
# Copying files: 22252 files [03:45, 102.43 files/s]
# Copying files: 22263 files [03:45, 103.14 files/s]
# Copying files: 22274 files [03:46, 103.64 files/s]
# Copying files: 22285 files [03:46, 103.70 files/s]
# Copying files: 22296 files [03:46, 102.87 files/s]
# Copying files: 22307 files [03:46, 102.87 files/s]
# Copying files: 22318 files [03:46, 102.58 files/s]
# Copying files: 22329 files [03:46, 102.66 files/s]
# Copying files: 22340 files [03:46, 102.44 files/s]
# Copying files: 22351 files [03:46, 99.24 files/s]
# Copying files: 22362 files [03:46, 100.85 files/s]
# Copying files: 22373 files [03:47, 101.73 files/s]
# Copying files: 22384 files [03:47, 103.80 files/s]
# Copying files: 22395 files [03:47, 104.10 files/s]
# Copying files: 22406 files [03:47, 102.57 files/s]
# Copying files: 22417 files [03:47, 103.24 files/s]
# Copying files: 22428 files [03:47, 103.42 files/s]
# Copying files: 22439 files [03:47, 103.22 files/s]
# Copying files: 22450 files [03:47, 101.97 files/s]
# Copying files: 22461 files [03:47, 101.95 files/s]
# Copying files: 22472 files [03:47, 103.38 files/s]
# Copying files: 22483 files [03:48, 104.10 files/s]
# Copying files: 22494 files [03:48, 102.57 files/s]
# Copying files: 22505 files [03:48, 103.53 files/s]
# Copying files: 22516 files [03:48, 103.04 files/s]
# Copying files: 22527 files [03:48, 103.86 files/s]
# Copying files: 22538 files [03:48, 104.15 files/s]
# Copying files: 22549 files [03:48, 102.89 files/s]
# Copying files: 22560 files [03:48, 102.59 files/s]
# Copying files: 22571 files [03:48, 104.13 files/s]
# Copying files: 22582 files [03:49, 104.94 files/s]
# Copying files: 22593 files [03:49, 104.90 files/s]
# Copying files: 22604 files [03:49, 103.40 files/s]
# Copying files: 22615 files [03:49, 103.53 files/s]
# Copying files: 22626 files [03:49, 103.04 files/s]
# Copying files: 22637 files [03:49, 103.28 files/s]
# Copying files: 22648 files [03:49, 103.74 files/s]
# Copying files: 22660 files [03:49, 107.20 files/s]
# Copying files: 22671 files [03:49, 106.80 files/s]
# Copying files: 22682 files [03:49, 107.12 files/s]
# Copying files: 22693 files [03:50, 107.36 files/s]
# Copying files: 22704 files [03:50, 107.52 files/s]
# Copying files: 22715 files [03:50, 107.64 files/s]
# Copying files: 22726 files [03:50, 107.40 files/s]
# Copying files: 22737 files [03:50, 106.31 files/s]
# Copying files: 22748 files [03:50, 104.66 files/s]
# Copying files: 22760 files [03:50, 106.35 files/s]
# Copying files: 22771 files [03:50, 106.80 files/s]
# Copying files: 22782 files [03:50, 103.84 files/s]
# Copying files: 22793 files [03:51, 104.42 files/s]
# Copying files: 22805 files [03:51, 106.17 files/s]
# Copying files: 22816 files [03:51, 106.98 files/s]
# Copying files: 22827 files [03:51, 105.43 files/s]
# Copying files: 22838 files [03:51, 104.66 files/s]
# Copying files: 22849 files [03:51, 105.61 files/s]
# Copying files: 22860 files [03:51, 105.98 files/s]
# Copying files: 22871 files [03:51, 105.92 files/s]
# Copying files: 22882 files [03:51, 104.39 files/s]
# Copying files: 22893 files [03:51, 103.03 files/s]
# Copying files: 22904 files [03:52, 104.74 files/s]
# Copying files: 22915 files [03:52, 105.07 files/s]
# Copying files: 22926 files [03:52, 104.99 files/s]
# Copying files: 22938 files [03:52, 105.99 files/s]
# Copying files: 22949 files [03:52, 106.55 files/s]
# Copying files: 22960 files [03:52, 106.64 files/s]
# Copying files: 22972 files [03:52, 108.03 files/s]
# Copying files: 22983 files [03:52, 108.00 files/s]
# Copying files: 22994 files [03:52, 107.04 files/s]
# Copying files: 23005 files [03:53, 106.07 files/s]
# Copying files: 23016 files [03:53, 106.61 files/s]
# Copying files: 23027 files [03:53, 107.31 files/s]
# Copying files: 23038 files [03:53, 106.86 files/s]
# Copying files: 23049 files [03:53, 99.90 files/s]
# Copying files: 23060 files [03:53, 100.50 files/s]
# Copying files: 23071 files [03:53, 102.04 files/s]
# Copying files: 23082 files [03:53, 103.15 files/s]
# Copying files: 23093 files [03:53, 102.20 files/s]
# Copying files: 23104 files [03:53, 102.40 files/s]
# Copying files: 23115 files [03:54, 103.12 files/s]
# Copying files: 23126 files [03:54, 104.51 files/s]
# Copying files: 23137 files [03:54, 104.90 files/s]
# Copying files: 23148 files [03:54, 104.88 files/s]
# Copying files: 23159 files [03:54, 103.68 files/s]
# Copying files: 23170 files [03:54, 103.14 files/s]
# Copying files: 23181 files [03:54, 103.64 files/s]
# Copying files: 23192 files [03:54, 101.97 files/s]
# Copying files: 23203 files [03:54, 101.67 files/s]
# Copying files: 23214 files [03:55, 100.91 files/s]
# Copying files: 23225 files [03:55, 102.05 files/s]
# Copying files: 23236 files [03:55, 101.73 files/s]
# Copying files: 23247 files [03:55, 103.19 files/s]
# Copying files: 23258 files [03:55, 102.23 files/s]
# Copying files: 23269 files [03:55, 102.14 files/s]
# Copying files: 23280 files [03:55, 102.64 files/s]
# Copying files: 23291 files [03:55, 102.14 files/s]
# Copying files: 23302 files [03:55, 101.23 files/s]
# Copying files: 23313 files [03:56, 101.43 files/s]
# Copying files: 23324 files [03:56, 101.30 files/s]
# Copying files: 23335 files [03:56, 99.28 files/s]
# Copying files: 23346 files [03:56, 100.33 files/s]
# Copying files: 23357 files [03:56, 101.64 files/s]
# Copying files: 23368 files [03:56, 99.79 files/s]
# Copying files: 23379 files [03:56, 101.25 files/s]
# Copying files: 23390 files [03:56, 102.29 files/s]
# Copying files: 23401 files [03:56, 102.18 files/s]
# Copying files: 23412 files [03:56, 102.10 files/s]
# Copying files: 23423 files [03:57, 101.20 files/s]
# Copying files: 23434 files [03:57, 101.69 files/s]
# Copying files: 23445 files [03:57, 101.20 files/s]
# Copying files: 23456 files [03:57, 102.26 files/s]
# Copying files: 23467 files [03:57, 103.31 files/s]
# Copying files: 23478 files [03:57, 102.03 files/s]
# Copying files: 23489 files [03:57, 100.05 files/s]
# Copying files: 23500 files [03:57, 101.15 files/s]
# Copying files: 23511 files [03:57, 102.23 files/s]
# Copying files: 23522 files [03:58, 102.71 files/s]
# Copying files: 23533 files [03:58, 103.63 files/s]
# Copying files: 23544 files [03:58, 105.17 files/s]
# Copying files: 23555 files [03:58, 105.67 files/s]
# Copying files: 23566 files [03:58, 105.12 files/s]
# Copying files: 23577 files [03:58, 105.03 files/s]
# Copying files: 23588 files [03:58, 104.37 files/s]
# Copying files: 23599 files [03:58, 104.21 files/s]
# Copying files: 23610 files [03:58, 105.29 files/s]
# Copying files: 23621 files [03:59, 104.55 files/s]
# Copying files: 23632 files [03:59, 104.04 files/s]
# Copying files: 23643 files [03:59, 104.28 files/s]
# Copying files: 23654 files [03:59, 104.14 files/s]
# Copying files: 23665 files [03:59, 104.65 files/s]
# Copying files: 23676 files [03:59, 104.70 files/s]
# Copying files: 23687 files [03:59, 105.34 files/s]
# Copying files: 23698 files [03:59, 105.18 files/s]
# Copying files: 23709 files [03:59, 104.78 files/s]
# Copying files: 23720 files [03:59, 105.09 files/s]
# Copying files: 23731 files [04:00, 105.31 files/s]
# Copying files: 23742 files [04:00, 106.39 files/s]
# Copying files: 23753 files [04:00, 107.15 files/s]
# Copying files: 23764 files [04:00, 107.06 files/s]
# Copying files: 23775 files [04:00, 105.47 files/s]
# Copying files: 23786 files [04:00, 104.67 files/s]
# Copying files: 23797 files [04:00, 105.62 files/s]
# Copying files: 23808 files [04:00, 105.69 files/s]
# Copying files: 23819 files [04:00, 105.43 files/s]
# Copying files: 23830 files [04:01, 105.55 files/s]
# Copying files: 23841 files [04:01, 105.94 files/s]
# Copying files: 23852 files [04:01, 105.30 files/s]
# Copying files: 23863 files [04:01, 104.56 files/s]
# Copying files: 23874 files [04:01, 104.04 files/s]
# Copying files: 23885 files [04:01, 104.28 files/s]
# Copying files: 23896 files [04:01, 104.74 files/s]
# Copying files: 23907 files [04:01, 104.47 files/s]
# Copying files: 23918 files [04:01, 103.08 files/s]
# Copying files: 23930 files [04:01, 105.53 files/s]
# Copying files: 23942 files [04:02, 107.83 files/s]
# Copying files: 23953 files [04:02, 108.15 files/s]
# Copying files: 23965 files [04:02, 108.75 files/s]
# Copying files: 23976 files [04:02, 108.82 files/s]
# Copying files: 23987 files [04:02, 108.24 files/s]
# Copying files: 23998 files [04:02, 108.46 files/s]
# Copying files: 24010 files [04:02, 108.99 files/s]
# Copying files: 24021 files [04:02, 108.05 files/s]
# Copying files: 24032 files [04:02, 106.17 files/s]
# Copying files: 24043 files [04:03, 105.47 files/s]
# Copying files: 24054 files [04:03, 105.58 files/s]
# Copying files: 24065 files [04:03, 105.96 files/s]
# Copying files: 24077 files [04:03, 107.55 files/s]
# Copying files: 24088 files [04:03, 107.97 files/s]
# Copying files: 24100 files [04:03, 108.96 files/s]
# Copying files: 24111 files [04:03, 108.65 files/s]
# Copying files: 24123 files [04:03, 109.43 files/s]
# Copying files: 24135 files [04:03, 110.25 files/s]
# Copying files: 24147 files [04:03, 109.91 files/s]
# Copying files: 24159 files [04:04, 110.91 files/s]
# Copying files: 24171 files [04:04, 110.07 files/s]
# Copying files: 24183 files [04:04, 109.19 files/s]
# Copying files: 24195 files [04:04, 110.08 files/s]
# Copying files: 24207 files [04:04, 109.20 files/s]
# Copying files: 24218 files [04:04, 107.63 files/s]
# Copying files: 24229 files [04:04, 107.71 files/s]
# Copying files: 24240 files [04:04, 107.77 files/s]
# Copying files: 24251 files [04:04, 106.89 files/s]
# Copying files: 24262 files [04:05, 106.88 files/s]
# Copying files: 24273 files [04:05, 106.57 files/s]
# Copying files: 24284 files [04:05, 105.44 files/s]
# Copying files: 24295 files [04:05, 104.95 files/s]
# Copying files: 24306 files [04:05, 104.32 files/s]
# Copying files: 24317 files [04:05, 103.59 files/s]
# Copying files: 24328 files [04:05, 104.85 files/s]
# Copying files: 24340 files [04:05, 106.48 files/s]
# Copying files: 24351 files [04:05, 105.99 files/s]
# Copying files: 24362 files [04:05, 104.46 files/s]
# Copying files: 24373 files [04:06, 103.69 files/s]
# Copying files: 24384 files [04:06, 103.44 files/s]
# Copying files: 24395 files [04:06, 104.14 files/s]
# Copying files: 24406 files [04:06, 104.05 files/s]
# Copying files: 24417 files [04:06, 104.28 files/s]
# Copying files: 24428 files [04:06, 104.15 files/s]
# Copying files: 24439 files [04:06, 104.06 files/s]
# Copying files: 24450 files [04:06, 103.70 files/s]
# Copying files: 24461 files [04:06, 103.74 files/s]
# Copying files: 24472 files [04:07, 103.18 files/s]
# Copying files: 24483 files [04:07, 104.26 files/s]
# Copying files: 24494 files [04:07, 102.39 files/s]
# Copying files: 24505 files [04:07, 101.96 files/s]
# Copying files: 24516 files [04:07, 103.68 files/s]
# Copying files: 24528 files [04:07, 105.66 files/s]
# Copying files: 24540 files [04:07, 107.01 files/s]
# Copying files: 24551 files [04:07, 106.67 files/s]
# Copying files: 24562 files [04:07, 104.91 files/s]
# Copying files: 24573 files [04:07, 106.08 files/s]
# Copying files: 24584 files [04:08, 105.11 files/s]
# Copying files: 24595 files [04:08, 104.73 files/s]
# Copying files: 24606 files [04:08, 105.05 files/s]
# Copying files: 24617 files [04:08, 103.20 files/s]
# Copying files: 24628 files [04:08, 103.10 files/s]
# Copying files: 24639 files [04:08, 102.74 files/s]
# Copying files: 24650 files [04:08, 103.36 files/s]
# Copying files: 24661 files [04:08, 104.38 files/s]
# Copying files: 24672 files [04:08, 103.92 files/s]
# Copying files: 24683 files [04:09, 104.49 files/s]
# Copying files: 24694 files [04:09, 103.12 files/s]
# Copying files: 24705 files [04:09, 104.81 files/s]
# Copying files: 24716 files [04:09, 106.03 files/s]
# Copying files: 24727 files [04:09, 106.90 files/s]
# Copying files: 24738 files [04:09, 107.51 files/s]
# Copying files: 24749 files [04:09, 107.32 files/s]
# Copying files: 24760 files [04:09, 107.81 files/s]
# Copying files: 24771 files [04:09, 105.06 files/s]
# Copying files: 24782 files [04:09, 104.39 files/s]
# Copying files: 24793 files [04:10, 103.35 files/s]
# Copying files: 24804 files [04:10, 104.67 files/s]
# Copying files: 24815 files [04:10, 104.42 files/s]
# Copying files: 24826 files [04:10, 104.24 files/s]
# Copying files: 24837 files [04:10, 103.24 files/s]
# Copying files: 24848 files [04:10, 103.42 files/s]
# Copying files: 24859 files [04:10, 104.73 files/s]
# Copying files: 24870 files [04:10, 105.66 files/s]
# Copying files: 24881 files [04:10, 106.02 files/s]
# Copying files: 24893 files [04:11, 107.92 files/s]
# Copying files: 24905 files [04:11, 109.54 files/s]
# Copying files: 24916 files [04:11, 109.06 files/s]
# Copying files: 24927 files [04:11, 108.72 files/s]
# Copying files: 24939 files [04:11, 109.79 files/s]
# Copying files: 24951 files [04:11, 110.22 files/s]
# Copying files: 24963 files [04:11, 109.89 files/s]
# Copying files: 24974 files [04:11, 109.32 files/s]
# Copying files: 24985 files [04:11, 108.90 files/s]
# Copying files: 25000 files [04:12, 99.19 files/s]

# %%
data_dir='dataset/aclImdb/dev/'
os.listdir(data_dir)
# Out:
# ['test', 'train']

# %%
os.listdir(f'{data_dir}/train')
# Out:
# ['neg', 'pos']

# %% [markdown]
# ### Statistics

# %%
all_filenames = glob(f'{data_dir}/*/*/*.txt')
num_words = [len(open(f, encoding="utf-8").read().split(' ')) for f in tqdm.notebook.tqdm(all_filenames)]

# print statistics
print('Min length =', min(num_words))
print('Max length =', max(num_words))

print('Mean = {:.2f}'.format(np.mean(num_words)))
print('Std  = {:.2f}'.format(np.std(num_words)))

print('mean + 2 * sigma = {:.2f}'.format(np.mean(num_words) + 2.0 * np.std(num_words)))
# Out:
#   0%|          | 0/3000 [00:00<?, ?it/s]
# Min length = 9
# Max length = 1090
# Mean = 228.50
# Std  = 170.35
# mean + 2 * sigma = 569.19

# %% [markdown]
# ## Dataset

# %%
PAD = '<pad>'  # special symbol we use for padding text
UNK = '<unk>'  # special symbol we use for rare or unknown word

# %%
class TextClassificationDataset(Dataset):
    
    def __init__(self, path, tokenizer, 
                 split='train', 
                 vocab_path='vocab.pkl', 
                 max_len=100, min_count=10):
        
        self.path = path
        assert split in ['train', 'test']
        self.split = split
        self.vocab_path = vocab_path
        self.tokenizer = tokenizer
        self.max_len = max_len
        self.min_count = min_count
        
        self.cache = {}
        self.vocab = None
        
        self.classes = []
        self.class_to_index = {}
        self.text_files = []
        
        split_path = f'{path}/{split}'
        
        for cls_idx, label in enumerate(os.listdir(split_path)):
            text_files = [(fname, cls_idx) for fname in glob(f'{split_path}/{label}/*.txt')]
            self.text_files += text_files
            self.classes += [label]
            self.class_to_index[label] = cls_idx
        
        self.num_classes = len(self.classes)
            
        # build vocabulary from training and validation texts
        self.build_vocab()
        
    def __getitem__(self, index):
        # read the tokenized text file and its label (neg=0, pos=1)
        fname, class_idx = self.text_files[index]
        
        if fname in self.cache:
            return self.cache[fname], class_idx
        
        # read text file 
        text = open(fname, encoding="utf-8").read()
        
        # tokenize the text file
        tokens = self.tokenizer(text.lower().strip())
        
        # padding and trimming
        if len(tokens) < self.max_len:
            num_pads = self.max_len - len(tokens)
            tokens = [PAD] * num_pads + tokens
        elif len(tokens) > self.max_len:
            tokens = tokens[:self.max_len]
            
        # numericalizing
        ids = torch.LongTensor(self.max_len)
        for i, word in enumerate(tokens):
            if word not in self.vocab.word2index:
                ids[i] = self.vocab.word2index[UNK]  # unknown words
            elif word != PAD and self.vocab.word2count[word] < self.min_count:
                ids[i] = self.vocab.word2index[UNK]  # rare words
            else:
                ids[i] = self.vocab.word2index[word]
                
        # save in cache for future use
        self.cache[fname] = ids
        
        return ids, class_idx
    
    def __len__(self):
        return len(self.text_files)
    
    def build_vocab(self):
        if not os.path.exists(self.vocab_path):
            vocab = Vocabulary(self.tokenizer)
            filenames = glob(f'{self.path}/*/*/*.txt')
            for filename in tqdm.notebook.tqdm(filenames, desc='Building Vocab'):
                with open(filename, encoding='utf8') as f:
                    for line in f:
                        vocab.add_sentence(line.lower())

            # sort words by their frequencies
            words = [(0, PAD), (0, UNK)]
            words += sorted([(c, w) for w, c in vocab.word2count.items()], reverse=True)

            self.vocab = Vocabulary(self.tokenizer)
            for i, (count, word) in enumerate(words):
                self.vocab.word2index[word] = i
                self.vocab.word2count[word] = count
                self.vocab.index2word[i] = word
                self.vocab.count += 1

            pickle.dump(self.vocab, open(self.vocab_path, 'wb'))
        else:
            self.vocab = pickle.load(open(self.vocab_path, 'rb'))

# %%
train_ds = TextClassificationDataset(data_dir, tokenizer, 'train', vocab_path, max_len, min_count)
train_dl = DataLoader(train_ds, batch_size=batch_size, shuffle=True)

valid_ds = TextClassificationDataset(data_dir, tokenizer, 'test', vocab_path, max_len, min_count)
valid_dl = DataLoader(valid_ds, batch_size=batch_size, shuffle=False)

# %%
len(train_ds)
# Out:
# 2500

# %%
len(valid_ds)
# Out:
# 500

# %%
train_ds.classes
# Out:
# ['neg', 'pos']

# %%
train_ds.class_to_index
# Out:
# {'neg': 0, 'pos': 1}

# %%
ids, label = train_ds[0]

print(train_ds.classes[label])
print(ids.numpy())
# Out:
# neg
# [   14     9    40   476     7   144     2  2236     7   213   116    30
#      2   176     4  3920     5   368     3    45    16    73   171   283
#    157   140     4     6   594   455     7     2   104  1174 14516  2030
#      7  1788  1640     5  1788  5044     3    41   147   259 13558   118
#    224   131    15    38    30  2196     7   124     3     5   124    82
#      4    49    28  1273    22    14    35     3   150    74   175   660
#    529     3     1    46   115   175   849  6226    21  1788  1640     3
#     46 21342  2813     2  2844     3  1999  2860    46  2399    21  1788
#   5044     5    74     2   154   804     4  1788  1640    16  2261  7362
#    421   633   170    14    25 18465    36     2  2702     3     5    13
#    155   137  1531    56     2  2143   960  5892    19   413    12    14
#     25    59     5   144     2  2143    83    31   219   295     2  2539
#    176   114    59    43  2062 21040     3   178    25    13   147   119
#     22   960  5892    55   101   400     2  2539   176  2101   114     3
#      5    36   228    12  2062    32   114  1083     3    71   103    11
#    666 16839    84   534    10    17    18    10   447     3    14     9
#    341   966   213  1164     4    45    30  3614]

# %%
# convert back the sequence of integers into original text
print(' '.join([train_ds.vocab.index2word[i.item()] for i in ids]))
# Out:
# this is an example of why the majority of action films are the same . generic and boring , there 's really nothing worth watching here . a complete waste of the then barely tapped talents of ice t and ice cube , who 've each proven many times over that they are capable of acting , and acting well . do n't bother with this one , go see new jack city , <unk> or watch new york undercover for ice t , or boyz n the hood , higher learning or friday for ice cube and see the real deal . ice t 's horribly cliched dialogue alone makes this film grate at the teeth , and i 'm still wondering what the heck bill paxton was doing in this film ? and why the heck does he always play the exact same character ? from aliens onward , every film i 've seen with bill paxton has him playing the exact same irritating character , and at least in aliens his character died , which made it somewhat gratifying ... <br > < br > overall , this is second rate action trash . there are countless

# %%
# print the original text
print(open(train_ds.text_files[0][0]).read())
# Out:
# This is an example of why the majority of action films are the same. Generic and boring, there's really nothing worth watching here. A complete waste of the then barely-tapped talents of Ice-T and Ice Cube, who've each proven many times over that they are capable of acting, and acting well. Don't bother with this one, go see New Jack City, Ricochet or watch New York Undercover for Ice-T, or Boyz n the Hood, Higher Learning or Friday for Ice Cube and see the real deal. Ice-T's horribly cliched dialogue alone makes this film grate at the teeth, and I'm still wondering what the heck Bill Paxton was doing in this film? And why the heck does he always play the exact same character? From Aliens onward, every film I've seen with Bill Paxton has him playing the exact same irritating character, and at least in Aliens his character died, which made it somewhat gratifying...<br /><br />Overall, this is second-rate action trash. There are countless better films to see, and if you really want to see this one, watch Judgement Night, which is practically a carbon copy but has better acting and a better script. The only thing that made this at all worth watching was a decent hand on the camera - the cinematography was almost refreshing, which comes close to making up for the horrible film itself - but not quite. 4/10.

# %% [markdown]
# ### Vovcabulary size

# %%
vocab = train_ds.vocab
freqs = [(count, word) for (word, count) in vocab.word2count.items() if count >= min_count]
vocab_size = len(freqs) + 2  # for PAD and UNK tokens
print(f'Vocab size = {vocab_size}')

print('\nMost common words:')
for c, w in sorted(freqs, reverse=True)[:10]:
    print(f'{w}: {c}')
# Out:
# Vocab size = 29506
#
# Most common words:
# the: 666713
# ,: 543467
# .: 470130
# and: 324156
# a: 321800
# of: 289313
# to: 267961
# is: 217022
# >: 202243
# it: 187974

# %% [markdown]
# ## LSTM Classifier with Attention mechanism

# %%
# Attention computes a weighted average of the hidden states of the LSTM Model.
# In fact, it produce a weight for each hidden state at different time steps

class SelfAttention(nn.Module):
    def __init__(self, hidden_dim):
        super().__init__()
        self.projection = nn.Sequential(
            nn.Linear(hidden_dim, 64),
            nn.ReLU(True),
            nn.Linear(64, 1)
        )
    
    def forward(self, encoder_outputs):
        # encoder_outputs = [batch size, sent len, hid dim]
        energy = self.projection(encoder_outputs)
        # energy = [batch size, sent len, 1]
        weights = F.softmax(energy.squeeze(-1), dim=1)
        # weights = [batch size, sent len]
        outputs = (encoder_outputs * weights.unsqueeze(-1)).sum(dim=1)
        # outputs = [batch size, hid dim]
        return outputs, weights

    
class AttentionLSTM(nn.Module):
    def __init__(self, vocab_size, embedding_dim, hidden_dim, output_dim, n_layers, bidirectional, dropout):
        super().__init__()
        self.hidden_dim = hidden_dim
        self.embedding_dim = embed_size
        self.num_layers = n_layers
        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        self.lstm = nn.LSTM(embedding_dim, hidden_dim, num_layers=n_layers,
                            bidirectional=bidirectional, 
                            dropout= 0 if n_layers < 2 else dropout)
        self.attention = SelfAttention(hidden_dim)
        self.fc = nn.Linear(hidden_dim, output_dim)
        self.dropout = nn.Dropout(dropout)
        
    def forward(self, x):
        # x = [sent len, batch size]
        embedded = self.embedding(x)
        # embedded = [sent len, batch size, emb dim]
        output, (hidden, cell) = self.lstm(embedded)
        # use 'batch_first' if you want batch size to be the 1st para
        # output = [sent len, batch size, hid dim*num directions]
        output = output[:, :, :self.hidden_dim] + output[:, :, self.hidden_dim:]
        # output = [sent len, batch size, hid dim]
        ouput = output.permute(1, 0, 2)
        # ouput = [batch size, sent len, hid dim]
        new_embed, weights = self.attention(ouput)
        # new_embed = [batch size, hid dim]
        # weights = [batch size, sent len]
        new_embed = self.dropout(new_embed)
        return self.fc(new_embed)

# %%
vocab_size = 2 + len([w for (w, c) in train_ds.vocab.word2count.items() if c >= min_count])
print(vocab_size)
# Out:
# 29506

# %% [markdown]
# ## Model

# %%
# LSTM parameters
embed_size = 100
hidden_size = 256 
num_layers = 1

# training parameters
lr = 0.001
num_epochs = 5

# %%
model = AttentionLSTM(vocab_size, embed_size, hidden_size, 
                      output_dim=train_ds.num_classes, 
                      n_layers=num_layers, bidirectional=True, dropout=0.5)


device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = model.to(device)

# %%
criterion = nn.CrossEntropyLoss().to(device)
criterion = criterion.to(device)
    
optimizer = optim.Adam(model.parameters(), lr=lr, betas=(0.7, 0.99))
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=1, gamma=0.9)

# %% [markdown]
# ### Training

# %%
hist = train(model, train_dl, valid_dl, criterion, optimizer, device, scheduler, num_epochs)
# Out:
# [Epoch:  1/ 5] | Training Loss: 0.0122 | Testing Loss: 0.0118 | Training Acc:           66.76 | Testing Acc: 70.60
# [Epoch:  2/ 5] | Training Loss: 0.0097 | Testing Loss: 0.0118 | Training Acc:           76.72 | Testing Acc: 70.80
# [Epoch:  3/ 5] | Training Loss: 0.0082 | Testing Loss: 0.0121 | Training Acc:           81.68 | Testing Acc: 73.20
# [Epoch:  4/ 5] | Training Loss: 0.0064 | Testing Loss: 0.0133 | Training Acc:           86.96 | Testing Acc: 71.80
# Training:   0%|          | 0/50 [00:00<?, ?it/s]
# Validation:   0%|          | 0/10 [00:00<?, ?it/s]

# %% [markdown]
# ### QRNN

# %% [markdown]
# <img src='imgs/QRNN.png' width='100%'/>
